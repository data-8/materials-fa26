# %% [markdown]
# # Tables

# %%
from datascience import *
import numpy as np

# %% [markdown]
# ## Arrays

# %%
a = make_array(5, 6, 7, 8)

# %% [markdown]
# * Array methods (for this class, just `.item()`)
# * Built-in array functions
# * NumPy array functions

# %% [markdown]
# ## Ranges ##

# %%
make_array(0, 1, 2, 3, 4, 5, 6)

# %%
np.arange(7)

# %%
np.arange(5, 11)

# %%
np.arange(0, 20, 2)

# %%
np.arange(0, 21, 2)

# %%
np.arange(0, 1, 0.1)

# %% [markdown]
# ## Columns of Tables are Arrays ##

# %%
nba_2026 = Table.read_table('nba_salaries.csv').where('season', 2026)
warriors = nba_2026.where('team', 'Golden State Warriors')

# %%
# how to see all 13 players on the team?
warriors

# %%
# what is the type of this expression?
warriors.select('salary')

# %%
# 1. how to get just the values in the column?
# 2. how to assign it to a name?

# %%
# 1. how to get steph curry's salary as a number?
# 2. what happens if he gets 5% more next year?

# %%
# what is the total salary payout to the team?

# %% [markdown]
# **Discuss**: What was the average salary among players on the warriors in the (2025-)2026 season? Start with the `warriors` table.

# %%
# ...(warriors...)

# %% [markdown]
# How does that average compare to the New York Knicks?

# %%
knicks = nba_2026.where('team', 'New York Knicks')
knicks

# %%
# compute the difference in averages

# %% [markdown]
# ---
#
# ## Create a table from columns

# %%
streets = make_array('Bancroft', 'Durant', 'Channing', 'Haste')
streets

# %%
Table()

# %%
southside = Table().with_column('Streets', streets)
southside

# %%
southside.with_column('Blocks from campus', np.arange(4))

# %%
Table().with_columns(
    'Streets', streets,
    'Blocks from campus', np.arange(4)
)

# %%
# how might I get "Channing" from this table?

# %% [markdown]
# ## W.E.B. Du Bois was a data scientist!
#
# https://en.wikipedia.org/wiki/W._E._B._Du_Bois

# %%
du_bois = Table.read_table('du_bois.csv')
du_bois

# %%
du_bois.column('ACTUAL AVERAGE')

# %%
du_bois.column('FOOD')

# %%
# how to get the average amount spent on food (by income bracket)?

# %%
# how to include this amount in table?

# %%
# how to reorder the columns?

# %% [markdown]
# Other things you can do with all tables
# * column labels
# * number of rows
# * number of columns

# %%
# one approach to discussion question

# %%
# alternate approach?
